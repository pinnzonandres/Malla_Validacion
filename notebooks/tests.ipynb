# %%
import pandas as pd
import sys

# %%
token = {
    "url": "https://as-rit-api-prod.azurewebsites.net/api/Sincronizador/resultados?id=212",
    "method": "GET",
    "headers": {
      "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjEiLCJSb2xJZCI6IjEiLCJFbWFpbCI6InN1cGVyYWRtaW5AcHNyaXRwcm9kLm9ubWljcm9zb2Z0LmNvbSIsIk5vbWJyZXMiOiJTdXBlciIsIkFwZWxsaWRvcyI6IkFkbWluIiwiTm9Eb2N1bWVudG8iOiIxMTExMTExMTEiLCJuYmYiOjE2NDM4OTQ2MjAsImV4cCI6MTcwNjk2NjYyMCwiaWF0IjoxNjQzODk0NjIwfQ.n3kaY2cLeeeUxHu4T8Xmol5nI8RRmoljYtRhujCDG7A"
    }
}

# %%
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)

# %%
sys.path.append('..\\scripts\\')

# %%
from MallaValidacionRuta import validacion

# %%
ruta = r"C:/Users/andre/OneDrive/Escritorio/DIP/03_Malla_Validación"

# %%
EmprendimientoColectivo = validacion(token = token, json_malla = True, nombre_malla = 'Malla_Emprendimiento_Colectivo', ruta = ruta)

# %%
test, validas, novalidas = EmprendimientoColectivo.validar_datos()
# Out:
# Dataframe Cargado desde el API
# Dataframe Expandido
# INICIO PROCESO DE VALIDACIÓN DE DATOS
# RESULTADOS MALLA DE VALIDACIÓN
# El número total de elementos validados fueron 261 participantes que equivale a 258 Hogares
# ...
# El número total de participantes con valores correctos es 212 que equivale a 210 hogares
# ...
# El número total de participantes con valores erroneos es 49 que equivale a 48 hogares
# FINZALIZACIÓN PROCESO DE VALIDACIÓN DE DATOS

# %%
novalidas
# Out:
#    ID_HOGAR  NUM_TITULAR  NUM_DOC_INTEGRANTE  Validacion  \
# 0    582510      8744587             8744587           7
# 1    582511      9146253             9146253           8
# 2    582515     15242678            15242678           8
# 3    582517     15243595            15243595           8
# 4    582519     18000929            18000929           1
# 5    582526     18008519            18008519           8
# 6    582527     18008786            18008786           1
# 7    582529     18009072            18009072           0
# 8    582529     18009072            18009072           2
# 9    582531     18010655            18010655           1
# 10   582532     18010705            18010705           8
# 11   582537     22371264            22371264           1
# 12   582547     25910046            25910046           1
# 13   582556     32846906            32846906           9
# 14   582559     33145768            33145768           1
# ...

# %%
EmprendimientoColectivo.dataframe.shape
# Out:
# (261, 238)

# %%
261*238
# Out:
# 62118

# %%
import sys
sys.path.append('..\\scripts\\')

# %%
ruta = r"C:/Users/andre/OneDrive/Escritorio/DIP/03_Malla_Validación"

# %%
from malla_functions import create_json_malla

# %%
create_json_malla()
